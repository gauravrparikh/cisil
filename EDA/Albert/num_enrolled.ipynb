# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Create Visualization for Enrollment in ORCA-LIFT
# New Visualization, May 7

# %%
LIFT_reg = pd.read_csv('/Users/albertsun/Projects/data/LIFT_registry_2022-04-01.csv')
LIFT_reg['stage'] = LIFT_reg['card_id'].str[-1:]
LIFT_reg['id'] = LIFT_reg['card_id'].str[:-2]
LIFT_reg['FIPS'] = LIFT_reg['FIPS'].astype(str).replace('\.0', '', regex=True)
uq_reg = LIFT_reg.sort_values('stage', ascending=False).drop_duplicates(['id'])
uq_reg = uq_reg[uq_reg.FIPS != 'nan'] # remove nan
uq_reg
# Out:
#         Age                   RaceDesc LanguageSpoken  Expiration  DateIssued  \
# 13395    40                      Asian        English   8/31/2023  2021-09-28
# 4794     41                      White        English   8/31/2023  2021-09-28
# 39267    66  Black or African American        English   8/31/2024  2021-10-13
# 10076    44  Black or African American        English   8/31/2023  2021-09-29
# 5499     61                      White        English   8/31/2023  2021-09-28
# ...     ...                        ...            ...         ...         ...
# 45465    27                      White        English   2/28/2021  2018-04-18
# 45464    37                      White        English  11/30/2020  2018-04-18
# 45463    26                      White        English   8/30/2019  2018-04-18
# 45462    35                      White        English   2/28/2021  2018-04-18
# 117727   33  Black or African American        English   3/31/2025  2022-03-17
#
# ...

# %%
uq_reg.stage = uq_reg.stage.astype(int)
uq_reg['reenrolled'] = np.where(uq_reg['stage'] > 1, True, False)
df_plot_load_stage = uq_reg[['Initial Load', 'stage']]
df_plot_load_stage.to_csv('/Users/albertsun/Projects/data/initialload_stage.csv')

# %%
uq_reg.value_counts
# Out:
# <bound method DataFrame.value_counts of         Age                   RaceDesc LanguageSpoken  Expiration  DateIssued  \
# 13395    40                      Asian        English   8/31/2023  2021-09-28
# 4794     41                      White        English   8/31/2023  2021-09-28
# 39267    66  Black or African American        English   8/31/2024  2021-10-13
# 10076    44  Black or African American        English   8/31/2023  2021-09-29
# 5499     61                      White        English   8/31/2023  2021-09-28
# ...     ...                        ...            ...         ...         ...
# 45465    27                      White        English   2/28/2021  2018-04-18
# 45464    37                      White        English  11/30/2020  2018-04-18
# 45463    26                      White        English   8/30/2019  2018-04-18
# 45462    35                      White        English   2/28/2021  2018-04-18
# ...

# %%
uq_reg.boxplot(column='stage', by='Count', return_type='axes')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-db9963ad12a7> in <module>
# ----> 1 uq_reg.boxplot(column='stage', by='Count', return_type='axes')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     509 ):
#     510     plot_backend = _get_plot_backend(backend)
# --> 511     return plot_backend.boxplot_frame(
#     512         self,
#     513         column=column,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     423     import matplotlib.pyplot as plt
#     424
# --> 425     ax = boxplot(
#     426         self,
#     427         column=column,
#
# ...

# %%
data_path = "/Users/albertsun/Projects/data/LIFT_registry_2022-04-01.csv"

# %%
import pandas as pd
import numpy as np

# %%
reg = pd.read_csv(data_path)

# %%
reg
# Out:
#         Age                   RaceDesc LanguageSpoken  Expiration  DateIssued  \
# 0        36  Black or African American          Other   8/31/2019  2017-06-15
# 1        56                      White        English   7/31/2019  2017-06-05
# 2        58                      White        English  11/30/2021  2019-08-28
# 3        49  Black or African American        English  11/30/2023  2022-01-26
# 4        46                      Asian        English   5/31/2021  2019-06-30
# ...     ...                        ...            ...         ...         ...
# 117723   26                      White        English   3/31/2025  2022-03-17
# 117724   26  Black or African American        English   3/31/2025  2022-03-17
# 117725   52                      White        English  10/31/2024  2022-03-17
# 117726   58  Black or African American        English   3/31/2025  2022-03-17
# 117727   33  Black or African American        English   3/31/2025  2022-03-17
#
# ...

# %% [markdown]
# # Re-enrollment Counts

# %%
reg['stage'] = reg['card_id'].str[-1:]
reg['id'] = reg['card_id'].str[:-2]
reg
# Out:
#         Age                   RaceDesc LanguageSpoken  Expiration  DateIssued  \
# 0        36  Black or African American          Other   8/31/2019  2017-06-15
# 1        56                      White        English   7/31/2019  2017-06-05
# 2        58                      White        English  11/30/2021  2019-08-28
# 3        49  Black or African American        English  11/30/2023  2022-01-26
# 4        46                      Asian        English   5/31/2021  2019-06-30
# ...     ...                        ...            ...         ...         ...
# 117723   26                      White        English   3/31/2025  2022-03-17
# 117724   26  Black or African American        English   3/31/2025  2022-03-17
# 117725   52                      White        English  10/31/2024  2022-03-17
# 117726   58  Black or African American        English   3/31/2025  2022-03-17
# 117727   33  Black or African American        English   3/31/2025  2022-03-17
#
# ...

# %%
reg
# Out:
#         Age                   RaceDesc LanguageSpoken  Expiration  DateIssued  \
# 0        36  Black or African American          Other   8/31/2019  2017-06-15
# 1        56                      White        English   7/31/2019  2017-06-05
# 2        58                      White        English  11/30/2021  2019-08-28
# 3        49  Black or African American        English  11/30/2023  2022-01-26
# 4        46                      Asian        English   5/31/2021  2019-06-30
# ...     ...                        ...            ...         ...         ...
# 117723   26                      White        English   3/31/2025  2022-03-17
# 117724   26  Black or African American        English   3/31/2025  2022-03-17
# 117725   52                      White        English  10/31/2024  2022-03-17
# 117726   58  Black or African American        English   3/31/2025  2022-03-17
# 117727   33  Black or African American        English   3/31/2025  2022-03-17
#
# ...

# %%
reg_grouped_id = reg.groupby(['id']).count()[['stage']]
reg_grouped_id
# Out:
#         stage
# id
# 100000      1
# 100002      2
# 100004      1
# 100006      2
# 100008      1
# ...       ...
# 99990       1
# 99992       2
# 99994       2
# 99996       1
# 99998       3
#
# [98228 rows x 1 columns]

# %%
total_reg = reg_grouped_id['stage'].value_counts().plot(kind='bar', title='How many times each person enrolled in ORCA-LIFT')
total_reg.set_xlabel("Times enrolled")
total_reg.set_ylabel("Number of People")
total_reg.figure.savefig('total_reg.png', bbox_inches='tight')

# %% [markdown]
# # Stacked Bar Plot

# %%
reg = reg.rename(columns={"Study Card": "study_card", "Initial Load": "initial_load"})
reg
# Out:
#         Age                   RaceDesc LanguageSpoken  Expiration  DateIssued  \
# 0        36  Black or African American          Other   8/31/2019  2017-06-15
# 1        56                      White        English   7/31/2019  2017-06-05
# 2        58                      White        English  11/30/2021  2019-08-28
# 3        49  Black or African American        English  11/30/2023  2022-01-26
# 4        46                      Asian        English   5/31/2021  2019-06-30
# ...     ...                        ...            ...         ...         ...
# 117723   26                      White        English   3/31/2025  2022-03-17
# 117724   26  Black or African American        English   3/31/2025  2022-03-17
# 117725   52                      White        English  10/31/2024  2022-03-17
# 117726   58  Black or African American        English   3/31/2025  2022-03-17
# 117727   33  Black or African American        English   3/31/2025  2022-03-17
#
# ...

# %%
reg['study_card'] = reg['study_card'].fillna(reg['initial_load'])
reg['study_card'] = reg.study_card.fillna('NaN')
reg.study_card.value_counts()
#reg.group_by('id')
# Out:
# NaN                       55968
# 10.0                      44339
# Subsidized Annual Pass    11666
# 15.0                       3858
# Phase2 Treatment            526
# 20.0                        494
# 50.0                        422
# Phase1 Treatment            187
# 70.0                        168
# 30.0                        100
# Name: study_card, dtype: int64

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(reg.head(100))
# Out:
#     Age                          RaceDesc LanguageSpoken  Expiration  \
# 0    36         Black or African American          Other   8/31/2019
# 1    56                             White        English   7/31/2019
# 2    58                             White        English  11/30/2021
# 3    49         Black or African American        English  11/30/2023
# 4    46                             Asian        English   5/31/2021
# 5    63                             Asian        Chinese   3/31/2019
# 6    64                             Asian        Chinese   6/30/2019
# 7    59                             Asian        Chinese   3/31/2019
# 8    60                             Asian        Chinese   6/30/2019
# 9    31         Black or African American         Somali   5/31/2019
# 10   33         Black or African American         Somali   6/30/2019
# 11   33         Black or African American         Somali   8/31/2021
# 12   61         Black or African American        English   3/31/2019
# ...

# %%
reg_first = reg[reg['stage'] == '1']

# id to study_card type mappings
reg_grouped_id_sc = reg_first[['id', 'study_card']].set_index('id')
reg_grouped_id_sc
# Out:
#                     study_card
# id
# 568                        NaN
# 2690                       NaN
# 2704                      10.0
# 2706                       NaN
# 2708                       NaN
# ...                        ...
# 272812                    10.0
# 272814                    10.0
# 272816  Subsidized Annual Pass
# 272818                    10.0
# 272820                    10.0
#
# [98228 rows x 1 columns]

# %%
# merged df with study cards and stages
id_sc_stage = pd.merge(reg_grouped_id_sc, reg_grouped_id, left_index=True, right_index=True)
id_sc_stage.to_csv("id_studycard_stage.csv")

# %%
# these are too slow: 
#id_sc_stage.plot.bar(stacked=True)
#id_sc_stage.plot.bar(rot=0)

# %%
multi = id_sc_stage.groupby(['study_card', 'stage']).size().unstack(fill_value=0)
multi.columns = multi.columns.astype(str)
multi = multi.div(multi.sum(axis=1), axis=0)

# %%
multi_t = multi.transpose()
multi_t.columns = multi_t.columns.astype(str)
multi_t = multi_t.rename(columns={'Phase1 Treatment': 'Phase1',
                       'Phase2 Treatment': 'Phase2',
                       'Subsidized Annual Pass': 'SAP'})

multi_t
# Out:
# study_card      10.0      15.0      20.0      30.0      50.0      70.0  \
# stage
# 1           0.912761  0.788847  0.850575  0.877778  0.878327  0.988889
# 2           0.068422  0.164321  0.112644  0.088889  0.102662  0.011111
# 3           0.014332  0.032756  0.025287  0.022222  0.003802  0.000000
# 4           0.003742  0.012182  0.009195  0.011111  0.015209  0.000000
# 5           0.000610  0.001354  0.002299  0.000000  0.000000  0.000000
# 6           0.000133  0.000541  0.000000  0.000000  0.000000  0.000000
# 8           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# study_card       NaN    Phase1    Phase2       SAP
# stage
# 1           0.807448  0.901639  0.834343  0.740875
# 2           0.146328  0.065574  0.133333  0.239232
# 3           0.036895  0.016393  0.020202  0.018336
# 4           0.007553  0.016393  0.008081  0.001384
# 5           0.001535  0.000000  0.004040  0.000173
# 6           0.000222  0.000000  0.000000  0.000000
# ...

# %%
len(multi['1'])
len(multi['2'])
len(multi_t.columns)
# Out:
# 10

# %%
import matplotlib.pyplot as plt

labels = multi_t.columns
width = .5 # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, multi['1'], width, label='1')
ax.bar(labels, multi['2'], width, bottom=multi['1'], label='2')
ax.bar(labels, multi['3'], width, bottom=multi['1'], label='3')
ax.bar(labels, multi['4'], width, bottom=multi['1'], label='4')
ax.bar(labels, multi['5'], width, bottom=multi['1'], label='5')
ax.bar(labels, multi['6'], width, bottom=multi['1'], label='6')
ax.bar(labels, multi['8'], width, bottom=multi['1'], label='8')


ax.set_ylabel('Count')
ax.set_title('How many times people enrolled in ORCA-LIFT based on Treatment')
ax.legend()
plt.legend(title = "# times enrolled")
plt.xticks(rotation = 45)
plt.show()
#fig.savefig('per_treatment_reg.png', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
width = .5 # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, label='Men')
ax.bar(labels, women_means, width, bottom=men_means, label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
reg[reg.id=='10016']
# Out:
#       Age                   RaceDesc LanguageSpoken  Expiration  DateIssued  \
# 2484   38  Black or African American        English  12/31/2020  2018-09-29
# 2485   40  Black or African American        English  10/31/2023  2021-01-25
# 2486   41  Black or African American        English  10/31/2024  2021-11-29
#
#               CardIssuingAgency          FIPS  initial_load  \
# 2484                        CCS  5.303300e+11           NaN
# 2485  King County Public Health  5.303300e+11           NaN
# 2486  King County Public Health  5.303303e+11           NaN
#
#                   study_card  card_id stage     id
# 2484                     NaN  10016-1     1  10016
# 2485  Subsidized Annual Pass  10016-2     2  10016
# 2486  Subsidized Annual Pass  10016-3     3  10016

# %%
groupby_counts = reg[reg.study_card=="Subsidized Annual Pass"].groupby('id').count()
groupby_counts
# Out:
#         Age  RaceDesc  LanguageSpoken  Expiration  DateIssued  \
# id
# 10016     2         2               2           2           2
# 100164    1         1               1           1           1
# 100210    2         2               2           2           2
# 100230    1         1               1           1           1
# 10036     2         2               2           2           2
# ...     ...       ...             ...         ...         ...
# 99662     2         2               2           2           2
# 9980      2         2               2           2           2
# 99818     1         1               1           1           1
# 99882     2         2               2           2           2
# 99888     1         1               1           1           1
#
#         CardIssuingAgency  FIPS  initial_load  study_card  card_id  stage
# id
# 10016                   2     2             0           2        2      2
# ...

# %%
import matplotlib.pyplot as plt

data = groupby_counts['stage'] 

d = np.diff(np.unique(data)).min()
left_of_first_bin = data.min() - float(d)/2
right_of_last_bin = data.max() + float(d)/2
plt.hist(data, np.arange(left_of_first_bin, right_of_last_bin + d, d))
plt.title('Distribution of ')
# Out:
# Text(0.5, 1.0, 'Distribution of ')
